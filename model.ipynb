# %%
import torch

# %%
# !ffmpeg
# Out:
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Hyper fast Audio and Video encoder
# usage: ffmpeg [options] [[infile options] -i infile]... {[outfile options] outfile}...
#
# Use -h to get full help or, even better, run 'man ffmpeg'

# %%
import torch.nn as nn
import torch
import yaml

def load_config(path="default.yaml") -> dict:
    with open(path, "r", encoding="utf-8") as ymlfile:
        cfg = yaml.safe_load(ymlfile)
    return cfg

class VideoClassificationModel(nn.Module):

    def __init__(self, cfg):
        super().__init__()

        self.cfg = cfg
        self.num_classes = cfg['num_classes']
        self.path_torchvideo_model = cfg['path_torchvideo_model']
        self.name_torchvideo_model = cfg['name_torchvideo_model']
        self.n_nodes = cfg["n_nodes"]
        self.freeze_layers = cfg.get("freeze_layers", 1.0) > 0.0
        self.dropout = cfg["dropout"]
        self.base_model = torch.hub.load(self.path_torchvideo_model, self.name_torchvideo_model, pretrained=True)

        if self.freeze_layers:
            print("Freeze layers of pretrained model")
            for name, param in self.base_model.named_parameters():
                param.requires_grad = False

        
        self.base_model.blocks[6].proj = nn.Sequential(nn.Linear(2304, self.n_nodes),
                                                        nn.ReLU(),
                                                        nn.Dropout(self.dropout),
                                                        nn.Linear(self.n_nodes, self.num_classes))

        for name, param in self.base_model.named_parameters():
            print("Layer name: {} - requires_grad: {}".format(name, param.requires_grad))
            
    def forward(self, x):
        x = self.base_model(x)
        return x

# %%
cfg = load_config()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = VideoClassificationModel(cfg).to(device)
# Out:
# Using cache found in C:\Users\leban/.cache\torch\hub\facebookresearch_pytorchvideo_main
# Freeze layers of pretrained model
# Layer name: blocks.0.multipathway_blocks.0.conv.weight - requires_grad: False
# Layer name: blocks.0.multipathway_blocks.0.norm.weight - requires_grad: False
# Layer name: blocks.0.multipathway_blocks.0.norm.bias - requires_grad: False
# Layer name: blocks.0.multipathway_blocks.1.conv.weight - requires_grad: False
# Layer name: blocks.0.multipathway_blocks.1.norm.weight - requires_grad: False
# Layer name: blocks.0.multipathway_blocks.1.norm.bias - requires_grad: False
# Layer name: blocks.0.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: blocks.0.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: blocks.0.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.1.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: blocks.1.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: blocks.1.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.2.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: blocks.2.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: blocks.2.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.3.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: blocks.3.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: blocks.3.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: blocks.6.proj.0.weight - requires_grad: True
# Layer name: blocks.6.proj.0.bias - requires_grad: True
# Layer name: blocks.6.proj.3.weight - requires_grad: True
# Layer name: blocks.6.proj.3.bias - requires_grad: True

# %%
import torch
import os
from pytorchvideo.data.encoded_video import EncodedVideo
from torchvision.transforms import Compose, Lambda, Resize
from torchvision.transforms._transforms_video import (
    CenterCropVideo,
    NormalizeVideo,
)
from pytorchvideo.transforms import (
    ApplyTransformToKey,
    ShortSideScale,
    UniformTemporalSubsample
)

import numpy as np
import pathlib

class PackPathway(torch.nn.Module):
    """
    Transform for converting video frames as a list of tensors. 
    """
    def __init__(self):
        super().__init__()
        
    def forward(self, frames: torch.Tensor):
        fast_pathway = frames
        # Perform temporal sampling from the fast pathway.
        slow_pathway = torch.index_select(
            frames,
            1,
            torch.linspace(
                0, frames.shape[1] - 1, frames.shape[1] // 4
            ).long(),
        )
        frame_list = [slow_pathway, fast_pathway]
        return frame_list


class ClassificationDataset(torch.utils.data.Dataset):
    def __init__(self, cfg, dataset_path, labelclass) -> None:
        super().__init__()
        self.labelclass=labelclass
        self.dataset_path = dataset_path
        self.cfg = cfg
        side_size = 256
        mean = [0.45, 0.45, 0.45]
        std = [0.225, 0.225, 0.225]
        crop_size = 256
        num_frames = cfg["num_frames"]
        #sampling_rate = cfg["sampling_rate"]
        #frames_per_second = cfg["frames_per_second"]
        do_crop_video = cfg.get("crop_video", 1.0) > 0.0

        if do_crop_video:
            print("do_crop_video TRUE")
            self.transform = ApplyTransformToKey(
                key="video",
                transform=Compose(
                    [
                        UniformTemporalSubsample(num_frames),
                        Lambda(lambda x: x/255.0),
                        NormalizeVideo(mean, std),
                        ShortSideScale(size=side_size),
                        CenterCropVideo(crop_size=(crop_size, crop_size)),
                        PackPathway()
                    ]
                ),
            )
        else:
            print("do_crop_video FALSE")
            self.transform = ApplyTransformToKey(
                key="video",
                transform=Compose(
                    [
                        UniformTemporalSubsample(num_frames),
                        Lambda(lambda x: x/255.0),
                        NormalizeVideo(mean, std),
                        #Resize((crop_size, crop_size)),
                        #ShortSideScale(size=side_size),
                        PackPathway()
                    ]
                ),
            )

    def __len__(self):
        return len(list(pathlib.Path(self.dataset_path).rglob("*.mp4")))

    def __getitem__(self, idx):
        video_path = str(list(pathlib.Path(self.dataset_path).rglob("*.mp4"))[idx])
        label = self.labelclass[list(pathlib.Path(self.dataset_path).rglob("*.mp4"))[idx].parent.name]

        if not os.path.exists(video_path):
            print("The video '{}' does not exist ".format(video_path))

        video = EncodedVideo.from_path(video_path)
        start_time = 0
        clip_duration = int(video.duration)
        end_sec = (cfg["num_frames"] * cfg["sampling_rate"])/cfg["frames_per_second"]
        video_data = video.get_clip(start_sec=start_time, end_sec=end_sec)
        video_data = self.transform(video_data)
        inputs = video_data["video"]

        return inputs, label
# Out:
# C:\Users\leban\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\transforms\_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# C:\Users\leban\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\transforms\_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %%
path = "C:\\Users\\leban\\Hahaton\\grouped"
labels = set([p.parent.name for p in list(pathlib.Path(path).rglob("*.mp4"))])
labelclass=dict()
i=0
for label in labels:
    labelclass[label]=i
    i+=1 #не очень умно, но время 2 ночи, а во мне полторы бутылки сидра

class2label = dict((v,k) for k,v in labelclass.items())

labelclass.update(class2label)

dataset = ClassificationDataset(cfg,path,labelclass)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
labels
# Out:
# do_crop_video TRUE
# {'cartwheel',
#  'catch',
#  'clap',
#  'climb',
#  'dive',
#  'draw_sword',
#  'dribble',
#  'fencing',
#  'flic_flac',
#  'golf',
#  'handstand',
#  'hit',
#  'jump',
#  'pick',
#  'pour',
#  'pullup',
#  'push',
#  'pushup',
#  'shoot_ball',
#  'sit',
#  'situp',
#  'swing_baseball',
#  'sword_exercise',
#  'throw'}

# %%
from torch.utils.data import DataLoader



batch_size = cfg['batch_size']
classification_dataloader_train = DataLoader(dataset=train_dataset,
                                                 batch_size=batch_size,
                                                 shuffle=True,
                                                 num_workers=0,
                                                 drop_last=True)
classification_dataloader_test = DataLoader(dataset=test_dataset,
                                                 batch_size=batch_size,
                                                 shuffle=True,
                                                 num_workers=0,
                                                 drop_last=True)

# %%
from tqdm import tqdm
import numpy as np
import random

post_act = torch.nn.Softmax(dim=1)

def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

def train_batch(inputs, labels, model, optimizer, criterion):
    model.train()
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return loss.item()


@torch.no_grad()
def accuracy(inputs, labels, model):
    model.eval()
    outputs = model(inputs)
    # Get the predicted classes
    preds = post_act(outputs)
    #print('preds: ', preds)
    _, pred_classes = torch.max(preds, 1)
    #print('pred_classes: ', pred_classes)
    #print('labels:', labels)
    is_correct = pred_classes == labels
    #print('is_correct: ', is_correct)
    return is_correct.cpu().numpy().tolist()


@torch.no_grad()
def val_loss(inputs, labels, model, criterion):
    model.eval()
    outputs = model(inputs)
    val_loss = criterion(outputs, labels)
    return val_loss.item()


def train_model(device,
                model,
                criterion,
                optimizer,
                lr_scheduler,
                classification_dataloader_train,
                classification_dataloader_val,
                best_epoch,
                num_epoch,
                best_val_epoch_accuracy,
                checkpoint_dir,
                saving_dir_experiments,
                logger,
                epoch_start_unfreeze=None,
                block_start_unfreeze=None):

    train_losses, train_accuracies = [], []
    val_losses, val_accuracies = [], []

    print("Start training")
    freezed = True
    for epoch in range(best_epoch, num_epoch):
        logger.log(f'Epoch {epoch}/{num_epoch - 1}')

        if epoch_start_unfreeze is not None and epoch >= epoch_start_unfreeze and freezed:
            print("****************************************")
            print("unfreeze the base model weights")

            if block_start_unfreeze is not None:
                print("unfreeze the layers greater and equal to unfreezing_block: ", block_start_unfreeze)
                #in this case unfreeze only the layers greater and equal the unfreezing_block layer
                for name, param in model.named_parameters():
                    if int(name.split(".")[2]) >= block_start_unfreeze:
                        param.requires_grad = True
            else:
                # in this case unfreeze all the layers of the model
                print("unfreeze all the layer of the model")
                for name, param in model.named_parameters():
                    param.requires_grad = True
            freezed = False

            for name, param in model.named_parameters():
                print("Layer name: {} - requires_grad: {}".format(name, param.requires_grad))
            print("****************************************")

        # define empty lists for the values of the loss and the accuracy of train and validation obtained in the batch of the current epoch
        # then at the end I take the average and I get the final values of the whole era
        train_epoch_losses, train_epoch_accuracies = [], []
        val_epoch_losses, val_epoch_accuracies = [], []

        # iterate on all train batches of the current epoch by executing the train_batch function
        for inputs, labels in tqdm(classification_dataloader_train, desc=f"epoch {str(epoch)} | train"):
            inputs = [i.to(device, non_blocking=True) for i in inputs]
            labels = labels.to(device, non_blocking=True)
            batch_loss = train_batch(inputs, labels, model, optimizer, criterion)
            train_epoch_losses.append(batch_loss)
        train_epoch_loss = np.array(train_epoch_losses).mean()

        # iterate on all train batches of the current epoch by calculating their accuracy
        for inputs, labels in tqdm(classification_dataloader_train, desc=f"epoch {str(epoch)} | train"):
            inputs = [i.to(device, non_blocking=True) for i in inputs]
            labels = labels.to(device, non_blocking=True)
            is_correct = accuracy(inputs, labels, model)
            train_epoch_accuracies.extend(is_correct)
        train_epoch_accuracy = np.mean(train_epoch_accuracies)

        # iterate on all batches of val of the current epoch by calculating the accuracy and the loss function
        for inputs, labels in tqdm(classification_dataloader_val, desc=f"epoch {str(epoch)} | val"):
            inputs = [i.to(device, non_blocking=True) for i in inputs]
            labels = labels.to(device)

            val_is_correct = accuracy(inputs, labels, model)
            val_epoch_accuracies.extend(val_is_correct)
        val_epoch_accuracy = np.mean(val_epoch_accuracies)

        phase = 'train'
        logger.log(f'{phase} LR: {lr_scheduler.get_last_lr()} - Loss: {train_epoch_loss:.4f} - Acc: {train_epoch_accuracy:.4f}')
        phase = 'val'
        print("Epoch: {} - LR:{} - Train Loss: {:.4f} - Train Acc: {:.4f} - Val Acc: {:.4f}".format(int(epoch), lr_scheduler.get_last_lr(), train_epoch_loss, train_epoch_accuracy,val_epoch_accuracy))
        logger.log("-----------")

        train_losses.append(train_epoch_loss)
        train_accuracies.append(train_epoch_accuracy)
        val_accuracies.append(val_epoch_accuracy)

        if best_val_epoch_accuracy < val_epoch_accuracy:
            print("We have a new best model! Save the model")

            #update best_val_epoch_accuracy
            best_val_epoch_accuracy = val_epoch_accuracy
            save_obj = {
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'scheduler': lr_scheduler.state_dict(),
                'epoch': epoch,
                'best_eva_accuracy': best_val_epoch_accuracy
            }
            print("Save best checkpoint at: ", os.path.join(checkpoint_dir, 'best.pth'))
            torch.save(save_obj, os.path.join(checkpoint_dir, 'best.pth'),  _use_new_zipfile_serialization=False)
            print("Save checkpoint at: ", os.path.join(checkpoint_dir, 'checkpoint_' + str(epoch) + '.pth'))
            torch.save(save_obj, os.path.join(checkpoint_dir, 'checkpoint_' + str(epoch) + '.pth'),  _use_new_zipfile_serialization=False)

        else:
            print("Save the current model")

            save_obj = {
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'scheduler': lr_scheduler.state_dict(),
                'epoch': epoch,
                'best_eva_accuracy': best_val_epoch_accuracy
            }
            print("Save checkpoint at: ", os.path.join(checkpoint_dir, 'checkpoint_' + str(epoch) + '.pth'))
            torch.save(save_obj, os.path.join(checkpoint_dir, 'checkpoint_' + str(epoch) + '.pth'),  _use_new_zipfile_serialization=False)

        lr_scheduler.step()
        torch.cuda.empty_cache()
        print("---------------------------------------------------------")

    print("End training")
    return

# %%
checkpoint = None
best_epoch = 0
best_val_epoch_accuracy = 0

dataset_path = cfg['dataset_path']

saving_dir_experiments = cfg['saving_dir_experiments']
saving_dir_model = cfg['saving_dir_model']

num_epoch = cfg['num_epoch']
learning_rate = cfg['learning_rate']
scheduler_step_size = cfg['scheduler_step_size']
scheduler_gamma = cfg['scheduler_gamma']
epoch_start_unfreeze = cfg.get("epoch_start_unfreeze", None)
block_start_unfreeze = cfg.get("block_start_unfreeze", None)

# 2 -  create the directory to save the results and checkpoints
print("Create the project structure")
print("saving_dir_experiments: ", saving_dir_experiments)
saving_dir_model = os.path.join(saving_dir_experiments, saving_dir_model)
print("saving_dir_model: ", saving_dir_model)
os.makedirs(saving_dir_experiments, exist_ok=True)
os.makedirs(saving_dir_model, exist_ok=True)

checkpoint_dir = saving_dir_model
# Out:
# Create the project structure
# saving_dir_experiments:  model_experiments_v1
# saving_dir_model:  model_experiments_v1\models_augmented_v1

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step_size, gamma=scheduler_gamma)
if checkpoint is not None:
    print('Load the optimizer from the last checkpoint')
    optimizer.load_state_dict(checkpoint['optimizer'])
    exp_lr_scheduler.load_state_dict(checkpoint["scheduler"])

    print('Latest epoch of the checkpoint: ', checkpoint['epoch'])
    print('Setting the new starting epoch: ', checkpoint['epoch'] + 1)
    best_epoch = checkpoint['epoch'] + 1

    print('Setting best_val_epoch_accuracy from checkpoint: ', checkpoint['best_eva_accuracy'])
    best_val_epoch_accuracy = checkpoint['best_eva_accuracy']

class Logger():
    def log(self, text): print(text)

train_model(device=device,
            model=model,
            criterion=criterion,
            optimizer=optimizer,
            lr_scheduler=exp_lr_scheduler,
            classification_dataloader_train=classification_dataloader_train,
            classification_dataloader_val=classification_dataloader_test,
            best_epoch=best_epoch,
            num_epoch=num_epoch,
            best_val_epoch_accuracy=best_val_epoch_accuracy,
            checkpoint_dir=checkpoint_dir,
            saving_dir_experiments=saving_dir_experiments,
            logger=Logger(),
            epoch_start_unfreeze=epoch_start_unfreeze,
            block_start_unfreeze=block_start_unfreeze,)
print("-------------------------------------------------------------------")
print("-------------------------------------------------------------------")
# Out:
# Start training
# Epoch 0/9
# epoch 0 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:38<00:00,  6.77s/it]
# epoch 0 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:38<00:00,  6.77s/it]
# epoch 0 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:20<00:00,  6.72s/it]
# train LR: [0.001] - Loss: 0.4604 - Acc: 0.9219
# Epoch: 0 - LR:[0.001] - Train Loss: 0.4604 - Train Acc: 0.9219 - Val Acc: 0.8802
# -----------
# We have a new best model! Save the model
# Save best checkpoint at:  model_experiments_v1\models_augmented_v1\best.pth
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_0.pth
# ---------------------------------------------------------
# Epoch 1/9
# epoch 1 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:39<00:00,  6.79s/it]
# epoch 1 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:36<00:00,  6.73s/it]
# epoch 1 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:21<00:00,  6.78s/it]
# train LR: [0.001] - Loss: 0.3233 - Acc: 0.9350
# Epoch: 1 - LR:[0.001] - Train Loss: 0.3233 - Train Acc: 0.9350 - Val Acc: 0.8750
# -----------
# Save the current model
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_1.pth
# ---------------------------------------------------------
# Epoch 2/9
# epoch 2 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:36<00:00,  6.73s/it]
# epoch 2 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:36<00:00,  6.73s/it]
# epoch 2 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:19<00:00,  6.64s/it]
# train LR: [0.001] - Loss: 0.2599 - Acc: 0.9519
# Epoch: 2 - LR:[0.001] - Train Loss: 0.2599 - Train Acc: 0.9519 - Val Acc: 0.8646
# -----------
# Save the current model
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_2.pth
# ---------------------------------------------------------
# Epoch 3/9
# epoch 3 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:34<00:00,  6.70s/it]
# epoch 3 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:31<00:00,  6.63s/it]
# epoch 3 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:19<00:00,  6.65s/it]
# train LR: [0.0001] - Loss: 0.1940 - Acc: 0.9744
# Epoch: 3 - LR:[0.0001] - Train Loss: 0.1940 - Train Acc: 0.9744 - Val Acc: 0.8984
# -----------
# We have a new best model! Save the model
# Save best checkpoint at:  model_experiments_v1\models_augmented_v1\best.pth
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_3.pth
# ---------------------------------------------------------
# Epoch 4/9
# epoch 4 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:34<00:00,  6.69s/it]
# epoch 4 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:31<00:00,  6.63s/it]
# epoch 4 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:19<00:00,  6.61s/it]
# train LR: [0.0001] - Loss: 0.1736 - Acc: 0.9738
# Epoch: 4 - LR:[0.0001] - Train Loss: 0.1736 - Train Acc: 0.9738 - Val Acc: 0.8932
# -----------
# Save the current model
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_4.pth
# ---------------------------------------------------------
# Epoch 5/9
# ****************************************
# unfreeze the base model weights
# unfreeze the layers greater and equal to unfreezing_block:  4
# Layer name: base_model.blocks.0.multipathway_blocks.0.conv.weight - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_blocks.0.norm.weight - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_blocks.0.norm.bias - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_blocks.1.conv.weight - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_blocks.1.norm.weight - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_blocks.1.norm.bias - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: base_model.blocks.0.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: base_model.blocks.1.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: base_model.blocks.2.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.bias - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_fusion.conv_fast_to_slow.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_fusion.norm.weight - requires_grad: False
# Layer name: base_model.blocks.3.multipathway_fusion.norm.bias - requires_grad: False
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch1_conv.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch1_conv.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight - requires_grad: True
# Layer name: base_model.blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias - requires_grad: True
# Layer name: base_model.blocks.6.proj.0.weight - requires_grad: True
# Layer name: base_model.blocks.6.proj.0.bias - requires_grad: True
# Layer name: base_model.blocks.6.proj.3.weight - requires_grad: True
# Layer name: base_model.blocks.6.proj.3.bias - requires_grad: True
# ****************************************
# epoch 5 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:39<00:00,  6.80s/it]
# epoch 5 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:32<00:00,  6.65s/it]
# epoch 5 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:19<00:00,  6.64s/it]
# train LR: [0.0001] - Loss: 0.1994 - Acc: 0.9956
# Epoch: 5 - LR:[0.0001] - Train Loss: 0.1994 - Train Acc: 0.9956 - Val Acc: 0.9036
# -----------
# We have a new best model! Save the model
# Save best checkpoint at:  model_experiments_v1\models_augmented_v1\best.pth
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_5.pth
# ---------------------------------------------------------
# Epoch 6/9
# epoch 6 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:42<00:00,  6.85s/it]
# epoch 6 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:34<00:00,  6.69s/it]
# epoch 6 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:20<00:00,  6.67s/it]
# train LR: [1e-05] - Loss: 0.0485 - Acc: 0.9988
# Epoch: 6 - LR:[1e-05] - Train Loss: 0.0485 - Train Acc: 0.9988 - Val Acc: 0.9010
# -----------
# Save the current model
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_6.pth
# ---------------------------------------------------------
# Epoch 7/9
# epoch 7 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:42<00:00,  6.86s/it]
# epoch 7 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:36<00:00,  6.73s/it]
# epoch 7 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:19<00:00,  6.61s/it]
# train LR: [1e-05] - Loss: 0.0360 - Acc: 0.9994
# Epoch: 7 - LR:[1e-05] - Train Loss: 0.0360 - Train Acc: 0.9994 - Val Acc: 0.9089
# -----------
# We have a new best model! Save the model
# Save best checkpoint at:  model_experiments_v1\models_augmented_v1\best.pth
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_7.pth
# ---------------------------------------------------------
# Epoch 8/9
# epoch 8 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:42<00:00,  6.85s/it]
# epoch 8 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:44<00:00,  6.90s/it]
# epoch 8 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:22<00:00,  6.89s/it]
# train LR: [1e-05] - Loss: 0.0270 - Acc: 0.9994
# Epoch: 8 - LR:[1e-05] - Train Loss: 0.0270 - Train Acc: 0.9994 - Val Acc: 0.9036
# -----------
# Save the current model
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_8.pth
# ---------------------------------------------------------
# Epoch 9/9
# epoch 9 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:41<00:00,  6.84s/it]
# epoch 9 | train: 100%|█████████████████████████████████████████████████████████████████| 50/50 [05:42<00:00,  6.85s/it]
# epoch 9 | val: 100%|███████████████████████████████████████████████████████████████████| 12/12 [01:23<00:00,  6.99s/it]
# train LR: [1.0000000000000002e-06] - Loss: 0.0221 - Acc: 0.9994
# Epoch: 9 - LR:[1.0000000000000002e-06] - Train Loss: 0.0221 - Train Acc: 0.9994 - Val Acc: 0.9089
# -----------
# Save the current model
# Save checkpoint at:  model_experiments_v1\models_augmented_v1\checkpoint_9.pth
# ---------------------------------------------------------
# End training
# -------------------------------------------------------------------
# -------------------------------------------------------------------

# %%
with torch.no_grad():
    for inputs, labels in classification_dataloader_test: # or i, image in enumerate(dataset)
            model.eval()
            outputs = model([i.to(device, non_blocking=True) for i in inputs])
            preds = post_act(outputs)
            _, pred_classes = torch.max(preds, 1)
            print(pred_classes)
            print([class2label[cl.item()] for cl in pred_classes])
            print(labels)
            print([class2label[cl.item()] for cl in labels])
            print((pred_classes == labels.to(device)))
# Out:
# tensor([19, 10,  4, 19,  4,  7,  4, 21, 23,  2, 14, 21,  7, 18, 17,  4, 11,  5,
#         18, 17, 22, 23, 12, 12, 15, 10, 21, 18,  0, 12, 11, 23],
#        device='cuda:0')
# ['fencing', 'shoot_ball', 'pick', 'fencing', 'pick', 'sword_exercise', 'pick', 'handstand', 'dribble', 'climb', 'dive', 'handstand', 'sword_exercise', 'golf', 'draw_sword', 'pick', 'clap', 'cartwheel', 'golf', 'draw_sword', 'swing_baseball', 'dribble', 'pullup', 'pullup', 'hit', 'shoot_ball', 'handstand', 'golf', 'flic_flac', 'pullup', 'clap', 'dribble']
# tensor([19, 10,  4, 19,  4,  7,  4, 21, 23,  2, 14, 21, 17, 18, 17,  4, 11,  5,
#         18, 17, 22, 23, 12, 12, 15, 10, 21, 18,  0, 12, 11, 23])
# ['fencing', 'shoot_ball', 'pick', 'fencing', 'pick', 'sword_exercise', 'pick', 'handstand', 'dribble', 'climb', 'dive', 'handstand', 'draw_sword', 'golf', 'draw_sword', 'pick', 'clap', 'cartwheel', 'golf', 'draw_sword', 'swing_baseball', 'dribble', 'pullup', 'pullup', 'hit', 'shoot_ball', 'handstand', 'golf', 'flic_flac', 'pullup', 'clap', 'dribble']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([16,  7, 14, 11,  4, 19, 11, 16, 15, 18, 16, 18, 18, 20, 16, 22,  3,  0,
#          0, 19,  3, 23,  3,  0,  2, 10,  8, 16,  5,  4, 22, 20],
#        device='cuda:0')
# ['sit', 'sword_exercise', 'dive', 'clap', 'pick', 'fencing', 'clap', 'sit', 'hit', 'golf', 'sit', 'golf', 'golf', 'throw', 'sit', 'swing_baseball', 'jump', 'flic_flac', 'flic_flac', 'fencing', 'jump', 'dribble', 'jump', 'flic_flac', 'climb', 'shoot_ball', 'push', 'sit', 'cartwheel', 'pick', 'swing_baseball', 'throw']
# tensor([16, 20, 14, 11,  4, 19, 11, 16, 15, 18, 16, 18, 18, 20, 16, 22,  3,  0,
#          0, 19,  3, 23,  3,  0,  2, 10,  8, 16,  5,  4, 22, 20])
# ['sit', 'throw', 'dive', 'clap', 'pick', 'fencing', 'clap', 'sit', 'hit', 'golf', 'sit', 'golf', 'golf', 'throw', 'sit', 'swing_baseball', 'jump', 'flic_flac', 'flic_flac', 'fencing', 'jump', 'dribble', 'jump', 'flic_flac', 'climb', 'shoot_ball', 'push', 'sit', 'cartwheel', 'pick', 'swing_baseball', 'throw']
# tensor([ True, False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([17, 22,  9,  5, 16, 10, 10, 23,  6,  4, 13, 12,  5,  7, 20,  3, 17, 16,
#         22,  4,  0, 10,  6, 16,  6, 20, 14,  3, 17, 22,  3, 13],
#        device='cuda:0')
# ['draw_sword', 'swing_baseball', 'pushup', 'cartwheel', 'sit', 'shoot_ball', 'shoot_ball', 'dribble', 'situp', 'pick', 'pour', 'pullup', 'cartwheel', 'sword_exercise', 'throw', 'jump', 'draw_sword', 'sit', 'swing_baseball', 'pick', 'flic_flac', 'shoot_ball', 'situp', 'sit', 'situp', 'throw', 'dive', 'jump', 'draw_sword', 'swing_baseball', 'jump', 'pour']
# tensor([17, 22,  9,  5, 16, 10, 10, 23,  6,  4, 13, 12,  5,  7, 20,  3, 17, 16,
#         22,  8,  0, 10,  6, 16,  6, 20, 14,  3, 17, 22,  3, 13])
# ['draw_sword', 'swing_baseball', 'pushup', 'cartwheel', 'sit', 'shoot_ball', 'shoot_ball', 'dribble', 'situp', 'pick', 'pour', 'pullup', 'cartwheel', 'sword_exercise', 'throw', 'jump', 'draw_sword', 'sit', 'swing_baseball', 'push', 'flic_flac', 'shoot_ball', 'situp', 'sit', 'situp', 'throw', 'dive', 'jump', 'draw_sword', 'swing_baseball', 'jump', 'pour']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([16, 15, 16, 13, 16, 23, 19, 10, 17,  4,  0, 14, 16, 12,  2,  2,  8, 16,
#         20, 16, 21, 16,  8, 10, 11, 10, 17, 15,  6, 10, 15,  5],
#        device='cuda:0')
# ['sit', 'hit', 'sit', 'pour', 'sit', 'dribble', 'fencing', 'shoot_ball', 'draw_sword', 'pick', 'flic_flac', 'dive', 'sit', 'pullup', 'climb', 'climb', 'push', 'sit', 'throw', 'sit', 'handstand', 'sit', 'push', 'shoot_ball', 'clap', 'shoot_ball', 'draw_sword', 'hit', 'situp', 'shoot_ball', 'hit', 'cartwheel']
# tensor([20, 15, 15, 13, 16, 23, 19, 10, 17,  4,  0, 14, 16, 12,  2,  2,  8, 16,
#         20, 16, 21, 16,  8, 10, 11, 10, 17, 15,  6, 10, 15,  5])
# ['throw', 'hit', 'hit', 'pour', 'sit', 'dribble', 'fencing', 'shoot_ball', 'draw_sword', 'pick', 'flic_flac', 'dive', 'sit', 'pullup', 'climb', 'climb', 'push', 'sit', 'throw', 'sit', 'handstand', 'sit', 'push', 'shoot_ball', 'clap', 'shoot_ball', 'draw_sword', 'hit', 'situp', 'shoot_ball', 'hit', 'cartwheel']
# tensor([False,  True, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([22,  6,  9,  3, 15, 10, 15, 15,  0,  6, 15,  0, 13, 23, 22,  7,  6, 18,
#         13,  6, 18,  3,  9, 13, 14, 15, 18, 21,  4, 23, 19,  8],
#        device='cuda:0')
# ['swing_baseball', 'situp', 'pushup', 'jump', 'hit', 'shoot_ball', 'hit', 'hit', 'flic_flac', 'situp', 'hit', 'flic_flac', 'pour', 'dribble', 'swing_baseball', 'sword_exercise', 'situp', 'golf', 'pour', 'situp', 'golf', 'jump', 'pushup', 'pour', 'dive', 'hit', 'golf', 'handstand', 'pick', 'dribble', 'fencing', 'push']
# tensor([ 3,  6,  9,  3, 15, 10, 15, 15,  0,  6, 20,  0, 13, 23, 22,  7,  6, 18,
#         13,  6, 18,  3,  9, 13, 14, 15, 18, 21,  4, 23, 19,  8])
# ['jump', 'situp', 'pushup', 'jump', 'hit', 'shoot_ball', 'hit', 'hit', 'flic_flac', 'situp', 'throw', 'flic_flac', 'pour', 'dribble', 'swing_baseball', 'sword_exercise', 'situp', 'golf', 'pour', 'situp', 'golf', 'jump', 'pushup', 'pour', 'dive', 'hit', 'golf', 'handstand', 'pick', 'dribble', 'fencing', 'push']
# tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([23, 23, 18, 12, 18,  0, 16,  4, 10, 22,  0, 22, 16, 15,  1,  6, 22,  8,
#          4,  0,  9, 23, 10, 17,  9,  6, 16,  3, 15, 22,  5, 15],
#        device='cuda:0')
# ['dribble', 'dribble', 'golf', 'pullup', 'golf', 'flic_flac', 'sit', 'pick', 'shoot_ball', 'swing_baseball', 'flic_flac', 'swing_baseball', 'sit', 'hit', 'catch', 'situp', 'swing_baseball', 'push', 'pick', 'flic_flac', 'pushup', 'dribble', 'shoot_ball', 'draw_sword', 'pushup', 'situp', 'sit', 'jump', 'hit', 'swing_baseball', 'cartwheel', 'hit']
# tensor([23, 23, 18, 12, 18,  0, 16,  4, 10, 22,  0, 22, 16, 15,  1,  6, 22,  8,
#          4,  0,  9, 23, 10, 17,  9,  6, 16,  3, 15, 22,  5, 15])
# ['dribble', 'dribble', 'golf', 'pullup', 'golf', 'flic_flac', 'sit', 'pick', 'shoot_ball', 'swing_baseball', 'flic_flac', 'swing_baseball', 'sit', 'hit', 'catch', 'situp', 'swing_baseball', 'push', 'pick', 'flic_flac', 'pushup', 'dribble', 'shoot_ball', 'draw_sword', 'pushup', 'situp', 'sit', 'jump', 'hit', 'swing_baseball', 'cartwheel', 'hit']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([12, 20,  0,  6,  9, 12, 19,  1, 16,  8,  3, 20,  1,  6, 20,  1,  6, 20,
#         19, 16,  5, 15,  3, 13, 12, 22,  9,  7,  3, 13,  5, 17],
#        device='cuda:0')
# ['pullup', 'throw', 'flic_flac', 'situp', 'pushup', 'pullup', 'fencing', 'catch', 'sit', 'push', 'jump', 'throw', 'catch', 'situp', 'throw', 'catch', 'situp', 'throw', 'fencing', 'sit', 'cartwheel', 'hit', 'jump', 'pour', 'pullup', 'swing_baseball', 'pushup', 'sword_exercise', 'jump', 'pour', 'cartwheel', 'draw_sword']
# tensor([12, 20,  0,  6,  9, 12, 19,  1, 16,  8,  8, 20,  1,  6, 20,  1,  6, 22,
#         19, 20,  5, 15,  3, 13, 12, 22,  9,  7,  3, 13,  5, 17])
# ['pullup', 'throw', 'flic_flac', 'situp', 'pushup', 'pullup', 'fencing', 'catch', 'sit', 'push', 'push', 'throw', 'catch', 'situp', 'throw', 'catch', 'situp', 'swing_baseball', 'fencing', 'throw', 'cartwheel', 'hit', 'jump', 'pour', 'pullup', 'swing_baseball', 'pushup', 'sword_exercise', 'jump', 'pour', 'cartwheel', 'draw_sword']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True,  True,  True,  True,  True, False,  True, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([11, 21,  6,  7, 13,  7,  7,  7, 17,  4,  8, 11, 11, 13, 16,  4,  2,  5,
#         21,  6,  3,  5,  7, 22, 15,  5,  6,  7, 20,  9, 19,  4],
#        device='cuda:0')
# ['clap', 'handstand', 'situp', 'sword_exercise', 'pour', 'sword_exercise', 'sword_exercise', 'sword_exercise', 'draw_sword', 'pick', 'push', 'clap', 'clap', 'pour', 'sit', 'pick', 'climb', 'cartwheel', 'handstand', 'situp', 'jump', 'cartwheel', 'sword_exercise', 'swing_baseball', 'hit', 'cartwheel', 'situp', 'sword_exercise', 'throw', 'pushup', 'fencing', 'pick']
# tensor([11, 21,  6,  7, 13,  7,  7,  7, 17,  4,  8, 11, 11, 13, 16,  4,  2,  5,
#         21,  6,  3,  5,  7, 22, 15,  5,  6,  7, 20,  9, 19,  4])
# ['clap', 'handstand', 'situp', 'sword_exercise', 'pour', 'sword_exercise', 'sword_exercise', 'sword_exercise', 'draw_sword', 'pick', 'push', 'clap', 'clap', 'pour', 'sit', 'pick', 'climb', 'cartwheel', 'handstand', 'situp', 'jump', 'cartwheel', 'sword_exercise', 'swing_baseball', 'hit', 'cartwheel', 'situp', 'sword_exercise', 'throw', 'pushup', 'fencing', 'pick']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([ 6, 16, 10, 23, 21, 17, 18, 11,  5, 18,  7, 15, 22, 23, 12, 21,  6, 22,
#          7,  0, 18,  9, 21, 11,  7,  1,  6, 13,  2, 22, 18, 10],
#        device='cuda:0')
# ['situp', 'sit', 'shoot_ball', 'dribble', 'handstand', 'draw_sword', 'golf', 'clap', 'cartwheel', 'golf', 'sword_exercise', 'hit', 'swing_baseball', 'dribble', 'pullup', 'handstand', 'situp', 'swing_baseball', 'sword_exercise', 'flic_flac', 'golf', 'pushup', 'handstand', 'clap', 'sword_exercise', 'catch', 'situp', 'pour', 'climb', 'swing_baseball', 'golf', 'shoot_ball']
# tensor([ 6, 16, 10, 23, 21, 17, 18, 11,  5, 18,  7, 15, 22, 23, 12, 21,  6, 22,
#          7,  0, 18,  9, 21, 11,  7,  1,  6, 13,  2, 22, 18, 10])
# ['situp', 'sit', 'shoot_ball', 'dribble', 'handstand', 'draw_sword', 'golf', 'clap', 'cartwheel', 'golf', 'sword_exercise', 'hit', 'swing_baseball', 'dribble', 'pullup', 'handstand', 'situp', 'swing_baseball', 'sword_exercise', 'flic_flac', 'golf', 'pushup', 'handstand', 'clap', 'sword_exercise', 'catch', 'situp', 'pour', 'climb', 'swing_baseball', 'golf', 'shoot_ball']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([ 8, 22, 22, 14,  5, 23,  7, 17, 23, 12,  6,  3,  3, 13, 11,  5,  3, 21,
#          9,  1, 15,  3, 15, 16, 21, 12,  2, 16, 18,  5, 21, 19],
#        device='cuda:0')
# ['push', 'swing_baseball', 'swing_baseball', 'dive', 'cartwheel', 'dribble', 'sword_exercise', 'draw_sword', 'dribble', 'pullup', 'situp', 'jump', 'jump', 'pour', 'clap', 'cartwheel', 'jump', 'handstand', 'pushup', 'catch', 'hit', 'jump', 'hit', 'sit', 'handstand', 'pullup', 'climb', 'sit', 'golf', 'cartwheel', 'handstand', 'fencing']
# tensor([ 8, 22, 22, 14,  5, 23,  7, 17, 23, 12,  6,  3,  3, 13, 11,  5,  3, 21,
#          9,  1, 15,  3, 15, 16, 21, 12,  2, 16, 18,  5, 21, 19])
# ['push', 'swing_baseball', 'swing_baseball', 'dive', 'cartwheel', 'dribble', 'sword_exercise', 'draw_sword', 'dribble', 'pullup', 'situp', 'jump', 'jump', 'pour', 'clap', 'cartwheel', 'jump', 'handstand', 'pushup', 'catch', 'hit', 'jump', 'hit', 'sit', 'handstand', 'pullup', 'climb', 'sit', 'golf', 'cartwheel', 'handstand', 'fencing']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([ 5,  7,  1, 22, 18,  0, 16, 16, 21,  8, 20,  5, 22, 18, 16, 10,  9, 22,
#         22, 14,  3,  0, 15,  0, 13, 15, 22,  3,  3,  1,  4, 12],
#        device='cuda:0')
# ['cartwheel', 'sword_exercise', 'catch', 'swing_baseball', 'golf', 'flic_flac', 'sit', 'sit', 'handstand', 'push', 'throw', 'cartwheel', 'swing_baseball', 'golf', 'sit', 'shoot_ball', 'pushup', 'swing_baseball', 'swing_baseball', 'dive', 'jump', 'flic_flac', 'hit', 'flic_flac', 'pour', 'hit', 'swing_baseball', 'jump', 'jump', 'catch', 'pick', 'pullup']
# tensor([ 5,  7,  1, 22, 18,  0, 16, 16, 21,  8, 20,  5, 22, 18, 16, 10,  9, 22,
#         22, 14,  3,  0, 15,  0, 13, 19, 22,  3,  3,  1,  4, 12])
# ['cartwheel', 'sword_exercise', 'catch', 'swing_baseball', 'golf', 'flic_flac', 'sit', 'sit', 'handstand', 'push', 'throw', 'cartwheel', 'swing_baseball', 'golf', 'sit', 'shoot_ball', 'pushup', 'swing_baseball', 'swing_baseball', 'dive', 'jump', 'flic_flac', 'hit', 'flic_flac', 'pour', 'fencing', 'swing_baseball', 'jump', 'jump', 'catch', 'pick', 'pullup']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([ 5, 22,  3,  1,  7, 22, 16,  9,  3, 16, 19, 23, 23, 23, 19,  3, 15, 23,
#         10, 13,  3,  3, 11,  0,  2,  4,  9,  4,  6, 17,  5, 13],
#        device='cuda:0')
# ['cartwheel', 'swing_baseball', 'jump', 'catch', 'sword_exercise', 'swing_baseball', 'sit', 'pushup', 'jump', 'sit', 'fencing', 'dribble', 'dribble', 'dribble', 'fencing', 'jump', 'hit', 'dribble', 'shoot_ball', 'pour', 'jump', 'jump', 'clap', 'flic_flac', 'climb', 'pick', 'pushup', 'pick', 'situp', 'draw_sword', 'cartwheel', 'pour']
# tensor([ 5, 22,  3,  1,  7, 22, 16,  9,  3, 16, 19, 23, 23, 23, 19,  3, 15, 23,
#         10, 13,  3,  3, 11,  0,  2,  4,  9, 14,  6,  7,  5, 13])
# ['cartwheel', 'swing_baseball', 'jump', 'catch', 'sword_exercise', 'swing_baseball', 'sit', 'pushup', 'jump', 'sit', 'fencing', 'dribble', 'dribble', 'dribble', 'fencing', 'jump', 'hit', 'dribble', 'shoot_ball', 'pour', 'jump', 'jump', 'clap', 'flic_flac', 'climb', 'pick', 'pushup', 'dive', 'situp', 'sword_exercise', 'cartwheel', 'pour']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True, False,
#          True,  True], device='cuda:0')
# tensor([ 2, 11,  0, 22, 11, 18,  4, 23,  0, 19,  4, 14, 12,  2, 22,  5,  5, 17,
#         15,  7, 23, 10,  7,  5,  8, 12, 21, 23,  4,  0,  4, 22],
#        device='cuda:0')
# ['climb', 'clap', 'flic_flac', 'swing_baseball', 'clap', 'golf', 'pick', 'dribble', 'flic_flac', 'fencing', 'pick', 'dive', 'pullup', 'climb', 'swing_baseball', 'cartwheel', 'cartwheel', 'draw_sword', 'hit', 'sword_exercise', 'dribble', 'shoot_ball', 'sword_exercise', 'cartwheel', 'push', 'pullup', 'handstand', 'dribble', 'pick', 'flic_flac', 'pick', 'swing_baseball']
# tensor([ 2, 11,  0, 22, 11, 18,  4, 23,  0, 19,  4, 14, 12,  2, 22,  5,  5, 17,
#         15,  7, 23, 10, 17,  5,  8, 12, 21, 23,  4,  0,  4, 22])
# ['climb', 'clap', 'flic_flac', 'swing_baseball', 'clap', 'golf', 'pick', 'dribble', 'flic_flac', 'fencing', 'pick', 'dive', 'pullup', 'climb', 'swing_baseball', 'cartwheel', 'cartwheel', 'draw_sword', 'hit', 'sword_exercise', 'dribble', 'shoot_ball', 'draw_sword', 'cartwheel', 'push', 'pullup', 'handstand', 'dribble', 'pick', 'flic_flac', 'pick', 'swing_baseball']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([14,  8,  0, 17,  9, 10, 13, 15, 17, 19, 16, 22,  4, 17, 20,  3,  5,  6,
#         20, 13, 11, 21,  9, 15, 11,  7, 10, 12, 16, 19, 13,  6],
#        device='cuda:0')
# ['dive', 'push', 'flic_flac', 'draw_sword', 'pushup', 'shoot_ball', 'pour', 'hit', 'draw_sword', 'fencing', 'sit', 'swing_baseball', 'pick', 'draw_sword', 'throw', 'jump', 'cartwheel', 'situp', 'throw', 'pour', 'clap', 'handstand', 'pushup', 'hit', 'clap', 'sword_exercise', 'shoot_ball', 'pullup', 'sit', 'fencing', 'pour', 'situp']
# tensor([ 3,  8,  0,  7,  9, 10, 13, 15, 17, 19, 16, 22,  4, 17, 20,  3,  5,  6,
#         20, 13, 11, 21,  9, 15, 11,  7, 23, 12, 11, 19, 13,  6])
# ['jump', 'push', 'flic_flac', 'sword_exercise', 'pushup', 'shoot_ball', 'pour', 'hit', 'draw_sword', 'fencing', 'sit', 'swing_baseball', 'pick', 'draw_sword', 'throw', 'jump', 'cartwheel', 'situp', 'throw', 'pour', 'clap', 'handstand', 'pushup', 'hit', 'clap', 'sword_exercise', 'dribble', 'pullup', 'clap', 'fencing', 'pour', 'situp']
# tensor([False,  True,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True, False,  True, False,  True,
#          True,  True], device='cuda:0')
# tensor([16, 20, 14,  1, 13,  1,  6, 16, 23,  7, 19, 18, 20, 18, 16, 15,  9, 13,
#         18,  7,  8,  7,  5, 16,  5, 20,  9, 14, 22,  1,  1,  1],
#        device='cuda:0')
# ['sit', 'throw', 'dive', 'catch', 'pour', 'catch', 'situp', 'sit', 'dribble', 'sword_exercise', 'fencing', 'golf', 'throw', 'golf', 'sit', 'hit', 'pushup', 'pour', 'golf', 'sword_exercise', 'push', 'sword_exercise', 'cartwheel', 'sit', 'cartwheel', 'throw', 'pushup', 'dive', 'swing_baseball', 'catch', 'catch', 'catch']
# tensor([16, 20, 14,  1, 13,  1,  6, 16, 23,  7, 19, 18, 20, 18,  3, 15,  9, 13,
#         18,  7,  8,  7,  5, 16,  5,  3,  9, 14, 22,  1,  1,  1])
# ['sit', 'throw', 'dive', 'catch', 'pour', 'catch', 'situp', 'sit', 'dribble', 'sword_exercise', 'fencing', 'golf', 'throw', 'golf', 'jump', 'hit', 'pushup', 'pour', 'golf', 'sword_exercise', 'push', 'sword_exercise', 'cartwheel', 'sit', 'cartwheel', 'jump', 'pushup', 'dive', 'swing_baseball', 'catch', 'catch', 'catch']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([13, 20, 14, 12, 11,  0, 11,  2, 17, 15, 14,  9,  2, 14, 18, 21, 14,  3,
#          5, 20, 21, 22, 18,  0,  8, 10,  4, 18,  1, 23, 19, 10],
#        device='cuda:0')
# ['pour', 'throw', 'dive', 'pullup', 'clap', 'flic_flac', 'clap', 'climb', 'draw_sword', 'hit', 'dive', 'pushup', 'climb', 'dive', 'golf', 'handstand', 'dive', 'jump', 'cartwheel', 'throw', 'handstand', 'swing_baseball', 'golf', 'flic_flac', 'push', 'shoot_ball', 'pick', 'golf', 'catch', 'dribble', 'fencing', 'shoot_ball']
# tensor([13, 20, 14, 12, 11,  0, 11,  2,  7, 15, 14,  9,  2, 14, 18, 21, 14,  3,
#          5, 20, 21, 22, 18,  0,  8, 10,  4, 18,  1, 23, 19, 10])
# ['pour', 'throw', 'dive', 'pullup', 'clap', 'flic_flac', 'clap', 'climb', 'sword_exercise', 'hit', 'dive', 'pushup', 'climb', 'dive', 'golf', 'handstand', 'dive', 'jump', 'cartwheel', 'throw', 'handstand', 'swing_baseball', 'golf', 'flic_flac', 'push', 'shoot_ball', 'pick', 'golf', 'catch', 'dribble', 'fencing', 'shoot_ball']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([ 2,  4, 19, 22,  0,  9, 22,  4, 22, 12, 14,  3,  7, 20,  1, 21, 12,  6,
#         21, 11, 22,  1, 16, 16, 11, 20, 14,  8, 16, 11,  6,  3],
#        device='cuda:0')
# ['climb', 'pick', 'fencing', 'swing_baseball', 'flic_flac', 'pushup', 'swing_baseball', 'pick', 'swing_baseball', 'pullup', 'dive', 'jump', 'sword_exercise', 'throw', 'catch', 'handstand', 'pullup', 'situp', 'handstand', 'clap', 'swing_baseball', 'catch', 'sit', 'sit', 'clap', 'throw', 'dive', 'push', 'sit', 'clap', 'situp', 'jump']
# tensor([ 2,  4, 19, 22,  0,  9, 22,  4, 22, 12, 14,  3,  7, 20,  1, 21, 12,  6,
#         21, 11, 22,  1, 16, 16, 11, 20, 14,  8, 16, 11,  6,  3])
# ['climb', 'pick', 'fencing', 'swing_baseball', 'flic_flac', 'pushup', 'swing_baseball', 'pick', 'swing_baseball', 'pullup', 'dive', 'jump', 'sword_exercise', 'throw', 'catch', 'handstand', 'pullup', 'situp', 'handstand', 'clap', 'swing_baseball', 'catch', 'sit', 'sit', 'clap', 'throw', 'dive', 'push', 'sit', 'clap', 'situp', 'jump']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')

# %%
torch.save(model.state_dict(), 'model_weights.pth')

# %%
torch.save(model, 'model.pth')

# %%
device = torch.device("cuda")
m = torch.load("model.pth", map_location=device)

# %%
with torch.no_grad():
    for inputs, labels in classification_dataloader_test: # or i, image in enumerate(dataset)
            m.eval()
            outputs = m([i.to(device, non_blocking=True) for i in inputs])
            preds = post_act(outputs)
            _, pred_classes = torch.max(preds, 1)
            print(pred_classes)
            print([class2label[cl.item()] for cl in pred_classes])
            print(labels)
            print([class2label[cl.item()] for cl in labels])
            print((pred_classes == labels.to(device)))
# Out:
# tensor([15,  5, 15,  5, 22, 16,  5,  3,  9, 10,  0,  0,  3, 22,  0, 10,  0, 13,
#          0, 13,  1, 20,  7,  9,  8, 18, 15, 14, 16, 14, 12,  1],
#        device='cuda:0')
# ['hit', 'cartwheel', 'hit', 'cartwheel', 'swing_baseball', 'sit', 'cartwheel', 'jump', 'pushup', 'shoot_ball', 'flic_flac', 'flic_flac', 'jump', 'swing_baseball', 'flic_flac', 'shoot_ball', 'flic_flac', 'pour', 'flic_flac', 'pour', 'catch', 'throw', 'sword_exercise', 'pushup', 'push', 'golf', 'hit', 'dive', 'sit', 'dive', 'pullup', 'catch']
# tensor([15,  5, 15,  5, 22, 16,  5,  3,  9, 10,  0,  0,  3, 22,  0, 10,  0, 13,
#          0, 13,  1, 20,  7,  9,  8, 18, 15, 14, 16, 14, 12,  1])
# ['hit', 'cartwheel', 'hit', 'cartwheel', 'swing_baseball', 'sit', 'cartwheel', 'jump', 'pushup', 'shoot_ball', 'flic_flac', 'flic_flac', 'jump', 'swing_baseball', 'flic_flac', 'shoot_ball', 'flic_flac', 'pour', 'flic_flac', 'pour', 'catch', 'throw', 'sword_exercise', 'pushup', 'push', 'golf', 'hit', 'dive', 'sit', 'dive', 'pullup', 'catch']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([22,  0,  8, 15, 11,  1,  0,  3,  5, 10,  6,  9, 10,  7, 17,  5,  5,  7,
#         12, 12, 15, 17,  9, 22, 14, 12, 15, 23, 14,  6, 21, 22],
#        device='cuda:0')
# ['swing_baseball', 'flic_flac', 'push', 'hit', 'clap', 'catch', 'flic_flac', 'jump', 'cartwheel', 'shoot_ball', 'situp', 'pushup', 'shoot_ball', 'sword_exercise', 'draw_sword', 'cartwheel', 'cartwheel', 'sword_exercise', 'pullup', 'pullup', 'hit', 'draw_sword', 'pushup', 'swing_baseball', 'dive', 'pullup', 'hit', 'dribble', 'dive', 'situp', 'handstand', 'swing_baseball']
# tensor([22,  0,  8, 15, 11,  1,  0,  3,  5, 10,  6,  9, 10,  7,  7,  5,  5,  7,
#         12, 12, 15, 17,  9, 22, 14, 12, 15, 23, 14,  6, 21, 22])
# ['swing_baseball', 'flic_flac', 'push', 'hit', 'clap', 'catch', 'flic_flac', 'jump', 'cartwheel', 'shoot_ball', 'situp', 'pushup', 'shoot_ball', 'sword_exercise', 'sword_exercise', 'cartwheel', 'cartwheel', 'sword_exercise', 'pullup', 'pullup', 'hit', 'draw_sword', 'pushup', 'swing_baseball', 'dive', 'pullup', 'hit', 'dribble', 'dive', 'situp', 'handstand', 'swing_baseball']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([11, 17, 14, 13, 11, 22,  2, 18,  4, 23,  9, 15, 13, 12, 17, 23,  3, 13,
#         23, 16,  7, 12, 16,  3,  3,  1, 22, 14,  8, 16,  1, 18],
#        device='cuda:0')
# ['clap', 'draw_sword', 'dive', 'pour', 'clap', 'swing_baseball', 'climb', 'golf', 'pick', 'dribble', 'pushup', 'hit', 'pour', 'pullup', 'draw_sword', 'dribble', 'jump', 'pour', 'dribble', 'sit', 'sword_exercise', 'pullup', 'sit', 'jump', 'jump', 'catch', 'swing_baseball', 'dive', 'push', 'sit', 'catch', 'golf']
# tensor([11, 17, 14, 13, 11, 22,  2, 18,  4, 23,  9, 20, 13, 12, 17, 23,  3, 13,
#         23, 16,  7, 12, 16,  3,  3,  1, 22, 14,  8, 16,  1, 18])
# ['clap', 'draw_sword', 'dive', 'pour', 'clap', 'swing_baseball', 'climb', 'golf', 'pick', 'dribble', 'pushup', 'throw', 'pour', 'pullup', 'draw_sword', 'dribble', 'jump', 'pour', 'dribble', 'sit', 'sword_exercise', 'pullup', 'sit', 'jump', 'jump', 'catch', 'swing_baseball', 'dive', 'push', 'sit', 'catch', 'golf']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([23,  9,  0, 21,  7, 13,  0, 11, 20, 13,  8,  5, 13, 22, 10, 18, 14, 15,
#          8, 16, 22,  4,  4, 10, 23,  4,  3, 13,  6, 16, 14, 17],
#        device='cuda:0')
# ['dribble', 'pushup', 'flic_flac', 'handstand', 'sword_exercise', 'pour', 'flic_flac', 'clap', 'throw', 'pour', 'push', 'cartwheel', 'pour', 'swing_baseball', 'shoot_ball', 'golf', 'dive', 'hit', 'push', 'sit', 'swing_baseball', 'pick', 'pick', 'shoot_ball', 'dribble', 'pick', 'jump', 'pour', 'situp', 'sit', 'dive', 'draw_sword']
# tensor([23,  9,  0, 21,  7, 13,  0, 11, 20, 13,  8,  5, 13, 22, 10, 18, 14, 15,
#          8, 16, 22,  4,  4, 10, 23,  4,  3, 13,  6, 16, 14, 17])
# ['dribble', 'pushup', 'flic_flac', 'handstand', 'sword_exercise', 'pour', 'flic_flac', 'clap', 'throw', 'pour', 'push', 'cartwheel', 'pour', 'swing_baseball', 'shoot_ball', 'golf', 'dive', 'hit', 'push', 'sit', 'swing_baseball', 'pick', 'pick', 'shoot_ball', 'dribble', 'pick', 'jump', 'pour', 'situp', 'sit', 'dive', 'draw_sword']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([ 1,  4, 11, 21,  1, 16,  4,  3,  7, 23,  0,  8, 17, 20, 16, 16, 16, 19,
#          6, 21,  1,  3, 22, 19, 13, 15, 21,  2,  6, 23, 22, 19],
#        device='cuda:0')
# ['catch', 'pick', 'clap', 'handstand', 'catch', 'sit', 'pick', 'jump', 'sword_exercise', 'dribble', 'flic_flac', 'push', 'draw_sword', 'throw', 'sit', 'sit', 'sit', 'fencing', 'situp', 'handstand', 'catch', 'jump', 'swing_baseball', 'fencing', 'pour', 'hit', 'handstand', 'climb', 'situp', 'dribble', 'swing_baseball', 'fencing']
# tensor([ 1,  4, 11, 21,  1, 20,  4,  3,  7, 23,  0,  8, 17, 20, 16,  3, 16, 19,
#          6, 21,  1,  3, 22, 19, 13, 15, 21,  2,  6, 23, 22, 19])
# ['catch', 'pick', 'clap', 'handstand', 'catch', 'throw', 'pick', 'jump', 'sword_exercise', 'dribble', 'flic_flac', 'push', 'draw_sword', 'throw', 'sit', 'jump', 'sit', 'fencing', 'situp', 'handstand', 'catch', 'jump', 'swing_baseball', 'fencing', 'pour', 'hit', 'handstand', 'climb', 'situp', 'dribble', 'swing_baseball', 'fencing']
# tensor([ True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([18,  4,  8, 15,  4, 22, 19,  7, 22, 11, 23, 16, 18, 21,  6, 12, 17,  7,
#         11,  3,  3,  7, 22, 18, 12, 18,  4, 23,  4,  3, 20,  0],
#        device='cuda:0')
# ['golf', 'pick', 'push', 'hit', 'pick', 'swing_baseball', 'fencing', 'sword_exercise', 'swing_baseball', 'clap', 'dribble', 'sit', 'golf', 'handstand', 'situp', 'pullup', 'draw_sword', 'sword_exercise', 'clap', 'jump', 'jump', 'sword_exercise', 'swing_baseball', 'golf', 'pullup', 'golf', 'pick', 'dribble', 'pick', 'jump', 'throw', 'flic_flac']
# tensor([18,  4,  8, 15,  8, 22, 19, 17, 22, 11, 23, 16, 18, 21,  6, 12, 17,  7,
#         11,  3,  3,  7, 22, 18, 12, 18,  4, 23,  4,  3, 20,  0])
# ['golf', 'pick', 'push', 'hit', 'push', 'swing_baseball', 'fencing', 'draw_sword', 'swing_baseball', 'clap', 'dribble', 'sit', 'golf', 'handstand', 'situp', 'pullup', 'draw_sword', 'sword_exercise', 'clap', 'jump', 'jump', 'sword_exercise', 'swing_baseball', 'golf', 'pullup', 'golf', 'pick', 'dribble', 'pick', 'jump', 'throw', 'flic_flac']
# tensor([ True,  True,  True,  True, False,  True,  True, False,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([15,  4,  3,  6,  3, 19, 18, 15,  6, 22,  9,  3, 13,  3,  6,  6, 18,  7,
#         15, 16,  0, 12,  5,  0, 10,  0,  4, 12, 23, 10, 16,  2],
#        device='cuda:0')
# ['hit', 'pick', 'jump', 'situp', 'jump', 'fencing', 'golf', 'hit', 'situp', 'swing_baseball', 'pushup', 'jump', 'pour', 'jump', 'situp', 'situp', 'golf', 'sword_exercise', 'hit', 'sit', 'flic_flac', 'pullup', 'cartwheel', 'flic_flac', 'shoot_ball', 'flic_flac', 'pick', 'pullup', 'dribble', 'shoot_ball', 'sit', 'climb']
# tensor([15,  4,  3,  6,  3, 19, 18, 15,  6, 22,  9,  3, 13,  3,  6,  6, 18, 17,
#         15, 16,  0, 12,  5,  0, 10,  0,  4, 12, 23, 10, 16,  2])
# ['hit', 'pick', 'jump', 'situp', 'jump', 'fencing', 'golf', 'hit', 'situp', 'swing_baseball', 'pushup', 'jump', 'pour', 'jump', 'situp', 'situp', 'golf', 'draw_sword', 'hit', 'sit', 'flic_flac', 'pullup', 'cartwheel', 'flic_flac', 'shoot_ball', 'flic_flac', 'pick', 'pullup', 'dribble', 'shoot_ball', 'sit', 'climb']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([16,  4, 23, 13, 22, 13, 19, 21, 20,  0, 17,  3, 23, 16, 17, 17,  3, 15,
#         20,  1, 10, 16,  7,  7, 20, 12, 13,  9, 18,  7, 15, 18],
#        device='cuda:0')
# ['sit', 'pick', 'dribble', 'pour', 'swing_baseball', 'pour', 'fencing', 'handstand', 'throw', 'flic_flac', 'draw_sword', 'jump', 'dribble', 'sit', 'draw_sword', 'draw_sword', 'jump', 'hit', 'throw', 'catch', 'shoot_ball', 'sit', 'sword_exercise', 'sword_exercise', 'throw', 'pullup', 'pour', 'pushup', 'golf', 'sword_exercise', 'hit', 'golf']
# tensor([16,  4, 23, 13, 22, 13, 19, 21, 20,  0,  7,  3, 23, 16, 17, 17,  3, 15,
#         22,  1, 10, 16,  7,  7, 20, 12, 13,  9, 18,  7, 15, 18])
# ['sit', 'pick', 'dribble', 'pour', 'swing_baseball', 'pour', 'fencing', 'handstand', 'throw', 'flic_flac', 'sword_exercise', 'jump', 'dribble', 'sit', 'draw_sword', 'draw_sword', 'jump', 'hit', 'swing_baseball', 'catch', 'shoot_ball', 'sit', 'sword_exercise', 'sword_exercise', 'throw', 'pullup', 'pour', 'pushup', 'golf', 'sword_exercise', 'hit', 'golf']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True,  True,  True,  True,  True,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([ 6,  5,  7,  2,  3, 18,  4,  2,  5, 14, 23,  0, 14, 22,  7,  6, 21,  0,
#         14,  1, 16,  0, 22, 22, 20, 13,  4,  4,  6, 21,  3,  4],
#        device='cuda:0')
# ['situp', 'cartwheel', 'sword_exercise', 'climb', 'jump', 'golf', 'pick', 'climb', 'cartwheel', 'dive', 'dribble', 'flic_flac', 'dive', 'swing_baseball', 'sword_exercise', 'situp', 'handstand', 'flic_flac', 'dive', 'catch', 'sit', 'flic_flac', 'swing_baseball', 'swing_baseball', 'throw', 'pour', 'pick', 'pick', 'situp', 'handstand', 'jump', 'pick']
# tensor([ 6,  5,  7,  2,  3, 18, 14,  2,  5, 14, 23,  0, 14, 22,  7,  6, 21,  0,
#         14,  1, 16,  0, 22, 22, 20, 13,  4,  4,  6, 21,  3,  4])
# ['situp', 'cartwheel', 'sword_exercise', 'climb', 'jump', 'golf', 'dive', 'climb', 'cartwheel', 'dive', 'dribble', 'flic_flac', 'dive', 'swing_baseball', 'sword_exercise', 'situp', 'handstand', 'flic_flac', 'dive', 'catch', 'sit', 'flic_flac', 'swing_baseball', 'swing_baseball', 'throw', 'pour', 'pick', 'pick', 'situp', 'handstand', 'jump', 'pick']
# tensor([ True,  True,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([ 6,  9, 14, 10, 19,  7, 18, 16, 21,  3, 18, 13,  8, 21,  8, 15, 15, 12,
#         15, 21,  0, 22,  1,  1,  6,  5,  9,  3, 16, 16,  2,  0],
#        device='cuda:0')
# ['situp', 'pushup', 'dive', 'shoot_ball', 'fencing', 'sword_exercise', 'golf', 'sit', 'handstand', 'jump', 'golf', 'pour', 'push', 'handstand', 'push', 'hit', 'hit', 'pullup', 'hit', 'handstand', 'flic_flac', 'swing_baseball', 'catch', 'catch', 'situp', 'cartwheel', 'pushup', 'jump', 'sit', 'sit', 'climb', 'flic_flac']
# tensor([ 6,  9, 14, 10, 19, 20, 18, 20, 21,  8, 18, 13,  8, 21,  8, 15, 15, 12,
#         15, 21,  0, 22,  1,  1,  6,  5,  9,  3, 16, 16,  2,  0])
# ['situp', 'pushup', 'dive', 'shoot_ball', 'fencing', 'throw', 'golf', 'throw', 'handstand', 'push', 'golf', 'pour', 'push', 'handstand', 'push', 'hit', 'hit', 'pullup', 'hit', 'handstand', 'flic_flac', 'swing_baseball', 'catch', 'catch', 'situp', 'cartwheel', 'pushup', 'jump', 'sit', 'sit', 'climb', 'flic_flac']
# tensor([ True,  True,  True,  True,  True, False,  True, False,  True, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([23, 19,  2,  7, 10,  6, 22, 11, 18,  7, 16,  5, 21, 15,  5, 20, 18, 22,
#          4, 11,  7,  8, 15, 22, 16, 23, 11,  6,  8, 11,  9, 23],
#        device='cuda:0')
# ['dribble', 'fencing', 'climb', 'sword_exercise', 'shoot_ball', 'situp', 'swing_baseball', 'clap', 'golf', 'sword_exercise', 'sit', 'cartwheel', 'handstand', 'hit', 'cartwheel', 'throw', 'golf', 'swing_baseball', 'pick', 'clap', 'sword_exercise', 'push', 'hit', 'swing_baseball', 'sit', 'dribble', 'clap', 'situp', 'push', 'clap', 'pushup', 'dribble']
# tensor([23, 19,  2,  7, 10,  6, 22, 11, 18,  7, 16,  5, 21, 15,  5, 20, 18, 22,
#          4, 11,  7,  8, 15, 22, 16, 23, 11,  6,  8, 11,  9, 23])
# ['dribble', 'fencing', 'climb', 'sword_exercise', 'shoot_ball', 'situp', 'swing_baseball', 'clap', 'golf', 'sword_exercise', 'sit', 'cartwheel', 'handstand', 'hit', 'cartwheel', 'throw', 'golf', 'swing_baseball', 'pick', 'clap', 'sword_exercise', 'push', 'hit', 'swing_baseball', 'sit', 'dribble', 'clap', 'situp', 'push', 'clap', 'pushup', 'dribble']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([19, 12, 22, 22,  0, 19, 18,  4,  0,  6, 22, 11, 13, 18, 19, 15, 16, 16,
#         22, 11, 22, 18, 17,  5,  7,  6, 21,  5, 20, 10,  5, 21],
#        device='cuda:0')
# ['fencing', 'pullup', 'swing_baseball', 'swing_baseball', 'flic_flac', 'fencing', 'golf', 'pick', 'flic_flac', 'situp', 'swing_baseball', 'clap', 'pour', 'golf', 'fencing', 'hit', 'sit', 'sit', 'swing_baseball', 'clap', 'swing_baseball', 'golf', 'draw_sword', 'cartwheel', 'sword_exercise', 'situp', 'handstand', 'cartwheel', 'throw', 'shoot_ball', 'cartwheel', 'handstand']
# tensor([19, 12, 22,  3,  0, 19, 18,  4,  0,  6, 22, 11, 13, 18, 19, 20, 16, 16,
#         22, 11, 22, 18, 17,  5,  7,  6, 21,  5, 20, 10,  5, 21])
# ['fencing', 'pullup', 'swing_baseball', 'jump', 'flic_flac', 'fencing', 'golf', 'pick', 'flic_flac', 'situp', 'swing_baseball', 'clap', 'pour', 'golf', 'fencing', 'throw', 'sit', 'sit', 'swing_baseball', 'clap', 'swing_baseball', 'golf', 'draw_sword', 'cartwheel', 'sword_exercise', 'situp', 'handstand', 'cartwheel', 'throw', 'shoot_ball', 'cartwheel', 'handstand']
# tensor([ True,  True,  True, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([ 0, 16,  0, 23,  9, 14, 11, 15,  1,  7,  8, 12,  2,  2, 10, 15,  9, 10,
#          1, 13,  5,  6, 16,  3, 16, 16, 22,  9,  6,  6,  9,  1],
#        device='cuda:0')
# ['flic_flac', 'sit', 'flic_flac', 'dribble', 'pushup', 'dive', 'clap', 'hit', 'catch', 'sword_exercise', 'push', 'pullup', 'climb', 'climb', 'shoot_ball', 'hit', 'pushup', 'shoot_ball', 'catch', 'pour', 'cartwheel', 'situp', 'sit', 'jump', 'sit', 'sit', 'swing_baseball', 'pushup', 'situp', 'situp', 'pushup', 'catch']
# tensor([ 0, 11,  0, 23,  9, 14, 11, 15,  1,  7,  8, 12,  2,  2, 23, 15,  9, 10,
#          1, 13,  5,  6, 16,  3, 16, 16, 22,  9,  6,  6,  9,  1])
# ['flic_flac', 'clap', 'flic_flac', 'dribble', 'pushup', 'dive', 'clap', 'hit', 'catch', 'sword_exercise', 'push', 'pullup', 'climb', 'climb', 'dribble', 'hit', 'pushup', 'shoot_ball', 'catch', 'pour', 'cartwheel', 'situp', 'sit', 'jump', 'sit', 'sit', 'swing_baseball', 'pushup', 'situp', 'situp', 'pushup', 'catch']
# tensor([ True, False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([19, 23,  5, 12,  3, 11,  5, 14,  4,  5, 11, 15, 23,  4, 10, 20, 11, 20,
#         23, 21, 22,  7, 19, 16,  3,  6,  6, 22, 21,  5, 19, 14],
#        device='cuda:0')
# ['fencing', 'dribble', 'cartwheel', 'pullup', 'jump', 'clap', 'cartwheel', 'dive', 'pick', 'cartwheel', 'clap', 'hit', 'dribble', 'pick', 'shoot_ball', 'throw', 'clap', 'throw', 'dribble', 'handstand', 'swing_baseball', 'sword_exercise', 'fencing', 'sit', 'jump', 'situp', 'situp', 'swing_baseball', 'handstand', 'cartwheel', 'fencing', 'dive']
# tensor([19, 23,  5, 12,  3, 11,  5, 14,  4,  5, 11, 15, 23,  4, 10, 20, 11, 20,
#         23, 21, 22,  7, 19, 16,  3,  6,  6, 22, 21,  5, 19, 14])
# ['fencing', 'dribble', 'cartwheel', 'pullup', 'jump', 'clap', 'cartwheel', 'dive', 'pick', 'cartwheel', 'clap', 'hit', 'dribble', 'pick', 'shoot_ball', 'throw', 'clap', 'throw', 'dribble', 'handstand', 'swing_baseball', 'sword_exercise', 'fencing', 'sit', 'jump', 'situp', 'situp', 'swing_baseball', 'handstand', 'cartwheel', 'fencing', 'dive']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
# tensor([22,  2, 17,  3, 10, 17,  9, 15,  8, 10, 16,  7, 15, 21, 13, 10,  0, 20,
#         18,  5, 17,  4, 19, 22, 22,  3, 16,  5, 11,  5, 23,  4],
#        device='cuda:0')
# ['swing_baseball', 'climb', 'draw_sword', 'jump', 'shoot_ball', 'draw_sword', 'pushup', 'hit', 'push', 'shoot_ball', 'sit', 'sword_exercise', 'hit', 'handstand', 'pour', 'shoot_ball', 'flic_flac', 'throw', 'golf', 'cartwheel', 'draw_sword', 'pick', 'fencing', 'swing_baseball', 'swing_baseball', 'jump', 'sit', 'cartwheel', 'clap', 'cartwheel', 'dribble', 'pick']
# tensor([22,  2, 17,  3, 10, 17,  9, 19,  8, 10, 16,  7, 15, 21, 13, 10,  0, 20,
#         18,  5, 17,  4, 19, 22, 22,  3, 15,  5, 11,  5, 23,  4])
# ['swing_baseball', 'climb', 'draw_sword', 'jump', 'shoot_ball', 'draw_sword', 'pushup', 'fencing', 'push', 'shoot_ball', 'sit', 'sword_exercise', 'hit', 'handstand', 'pour', 'shoot_ball', 'flic_flac', 'throw', 'golf', 'cartwheel', 'draw_sword', 'pick', 'fencing', 'swing_baseball', 'swing_baseball', 'jump', 'hit', 'cartwheel', 'clap', 'cartwheel', 'dribble', 'pick']
# tensor([ True,  True,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([ 9, 19,  6,  9, 16, 17,  2, 14, 12, 15, 16,  7, 10, 15, 16,  1, 17, 14,
#         14, 11, 17, 19,  2, 22,  6,  2,  1,  4, 11, 16, 16, 11],
#        device='cuda:0')
# ['pushup', 'fencing', 'situp', 'pushup', 'sit', 'draw_sword', 'climb', 'dive', 'pullup', 'hit', 'sit', 'sword_exercise', 'shoot_ball', 'hit', 'sit', 'catch', 'draw_sword', 'dive', 'dive', 'clap', 'draw_sword', 'fencing', 'climb', 'swing_baseball', 'situp', 'climb', 'catch', 'pick', 'clap', 'sit', 'sit', 'clap']
# tensor([ 9, 19,  6,  9, 16, 17,  2, 14, 12, 15, 16,  7, 10, 15, 16,  1,  7, 14,
#          3, 11, 17, 19,  2, 22,  6,  2,  1,  4, 11, 16, 16, 11])
# ['pushup', 'fencing', 'situp', 'pushup', 'sit', 'draw_sword', 'climb', 'dive', 'pullup', 'hit', 'sit', 'sword_exercise', 'shoot_ball', 'hit', 'sit', 'catch', 'sword_exercise', 'dive', 'jump', 'clap', 'draw_sword', 'fencing', 'climb', 'swing_baseball', 'situp', 'climb', 'catch', 'pick', 'clap', 'sit', 'sit', 'clap']
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True, False,  True, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True], device='cuda:0')
# tensor([10, 23,  9, 22, 19, 16,  8, 20,  3, 13, 19, 12, 17, 21, 16, 18, 20, 18,
#          5,  5, 20, 12,  7, 16, 13, 12,  4,  2,  6, 23, 18, 20],
#        device='cuda:0')
# ['shoot_ball', 'dribble', 'pushup', 'swing_baseball', 'fencing', 'sit', 'push', 'throw', 'jump', 'pour', 'fencing', 'pullup', 'draw_sword', 'handstand', 'sit', 'golf', 'throw', 'golf', 'cartwheel', 'cartwheel', 'throw', 'pullup', 'sword_exercise', 'sit', 'pour', 'pullup', 'pick', 'climb', 'situp', 'dribble', 'golf', 'throw']
# tensor([10, 23,  9, 22, 19, 16,  8, 20,  3, 13, 19, 12, 17, 21, 16, 18, 20, 18,
#          5,  5, 20, 12,  7, 16, 13, 12,  4,  2,  6, 23, 18, 20])
# ['shoot_ball', 'dribble', 'pushup', 'swing_baseball', 'fencing', 'sit', 'push', 'throw', 'jump', 'pour', 'fencing', 'pullup', 'draw_sword', 'handstand', 'sit', 'golf', 'throw', 'golf', 'cartwheel', 'cartwheel', 'throw', 'pullup', 'sword_exercise', 'sit', 'pour', 'pullup', 'pick', 'climb', 'situp', 'dribble', 'golf', 'throw']
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True], device='cuda:0')
